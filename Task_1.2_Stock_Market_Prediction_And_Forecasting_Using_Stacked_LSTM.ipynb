# %% [markdown]
# <h1>LetsGrowMore #feb2022</h1>
# Author - RICHA GUPTA
#
#
# Task-1: Stock Market Prediction And Forecasting Using Stacked LSTM
#
# Level : Beginner
#
# Language-Python
#
# Software- Jupyter Notebook

# %% [markdown]
# <H2>Importing Libraries</H2>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <h2>Reading the DataSet</h2>

# %%
url="https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv"
stk = pd.read_csv(url)

# %%
stk.head() # Prints first Five Rows
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
stk.tail() # Prints last five rows
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
#
#       Turnover (Lacs)
# 2030           694.98
# 2031           780.01
# 2032           340.31
# 2033           355.17
# 2034           803.56

# %%
stk.describe() # Gives Statistical information like Mean, Median, Count, Standard deviation, Minimum value, Maximum value
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
stk.isnull() # Calculating null values in the Dataset
# Out:
#        Date   Open   High    Low   Last  Close  Total Trade Quantity  \
# 0     False  False  False  False  False  False                 False
# 1     False  False  False  False  False  False                 False
# 2     False  False  False  False  False  False                 False
# 3     False  False  False  False  False  False                 False
# 4     False  False  False  False  False  False                 False
# ...     ...    ...    ...    ...    ...    ...                   ...
# 2030  False  False  False  False  False  False                 False
# 2031  False  False  False  False  False  False                 False
# 2032  False  False  False  False  False  False                 False
# 2033  False  False  False  False  False  False                 False
# 2034  False  False  False  False  False  False                 False
#
#       Turnover (Lacs)
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 2030            False
# 2031            False
# 2032            False
# 2033            False
# 2034            False
#
# [2035 rows x 8 columns]

# %% [markdown]
# <h2> Sorting the Data</h2>

# %%
stk['Date']=pd.to_datetime(stk['Date'])
print(type(stk.Date[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df=stk.sort_values(by='Date')
df.head()
# Out:
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %%
df.reset_index(inplace=True) # Reset the index of the Dataframe

# %%
df.head()
# Out:
#    index       Date   Open    High     Low    Last   Close  \
# 0   2034 2010-07-21  122.1  123.00  121.05  121.10  121.55
# 1   2033 2010-07-22  120.3  122.00  120.25  120.75  120.90
# 2   2032 2010-07-23  121.8  121.95  120.25  120.35  120.65
# 3   2031 2010-07-26  120.1  121.00  117.10  117.10  117.60
# 4   2030 2010-07-27  117.6  119.50  112.00  118.80  118.65
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                658666           803.56
# 1                293312           355.17
# 2                281312           340.31
# 3                658440           780.01
# 4                586100           694.98

# %% [markdown]
# <h2>Data Visualization</h2>

# %%
plt.plot(df['Close'])

# %%
dff=df['Close']
dff
# Out:
# 0       121.55
# 1       120.90
# 2       120.65
# 3       117.60
# 4       118.65
#          ...
# 2030    233.30
# 2031    236.10
# 2032    234.25
# 2033    233.25
# 2034    233.75
# Name: Close, Length: 2035, dtype: float64

# %% [markdown]
# <h2>Min Max Scaler</h2>

# %%
scaler=MinMaxScaler(feature_range=(0,1))
dff=scaler.fit_transform(np.array(dff).reshape(-1,1))
dff
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %% [markdown]
# <h2>Spliting the Dataset</h2>

# %%
training_size=int(len(dff)*0.70)
test_size=len(dff)-training_size
train_data,test_data=dff[0:training_size,:],dff[training_size:len(dff),:1]

# %% [markdown]
# <h2>Converting an Array of values into a Dataset matrix</h2>

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# <h2>Spliting the Data into Train and Test</h2>

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1323, 100)
# (1323,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (510, 100)
# (510,)
# (None, None)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %% [markdown]
# <h2>Creating the stacked LSTM Model</h2>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_split=0.1,epochs=60,batch_size=64,verbose=1)
# Out:
# Epoch 1/60
# 19/19 [==============================] - 11s 254ms/step - loss: 0.0093 - val_loss: 0.0019
# Epoch 2/60
# 19/19 [==============================] - 3s 162ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 3/60
# 19/19 [==============================] - 3s 151ms/step - loss: 9.4881e-04 - val_loss: 0.0013
# Epoch 4/60
# 19/19 [==============================] - 3s 148ms/step - loss: 8.9312e-04 - val_loss: 0.0013
# Epoch 5/60
# 19/19 [==============================] - 3s 158ms/step - loss: 8.5477e-04 - val_loss: 0.0012
# Epoch 6/60
# 19/19 [==============================] - 3s 161ms/step - loss: 8.2688e-04 - val_loss: 0.0011
# Epoch 7/60
# 19/19 [==============================] - 3s 175ms/step - loss: 8.0773e-04 - val_loss: 0.0011
# Epoch 8/60
# 19/19 [==============================] - 4s 188ms/step - loss: 7.8492e-04 - val_loss: 0.0010
# Epoch 9/60
# 19/19 [==============================] - 3s 166ms/step - loss: 7.4570e-04 - val_loss: 9.7454e-04
# Epoch 10/60
# 19/19 [==============================] - 3s 162ms/step - loss: 7.2102e-04 - val_loss: 9.6409e-04
# Epoch 11/60
# 19/19 [==============================] - 3s 167ms/step - loss: 7.4347e-04 - val_loss: 9.0644e-04
# Epoch 12/60
# 19/19 [==============================] - 3s 165ms/step - loss: 6.6530e-04 - val_loss: 8.3729e-04
# Epoch 13/60
# 19/19 [==============================] - 3s 167ms/step - loss: 7.0776e-04 - val_loss: 7.6693e-04
# Epoch 14/60
# 19/19 [==============================] - 3s 153ms/step - loss: 6.3945e-04 - val_loss: 7.5616e-04
# Epoch 15/60
# 19/19 [==============================] - 3s 154ms/step - loss: 6.1271e-04 - val_loss: 7.7313e-04
# Epoch 16/60
# 19/19 [==============================] - 3s 170ms/step - loss: 6.0532e-04 - val_loss: 7.2774e-04
# Epoch 17/60
# 19/19 [==============================] - 3s 164ms/step - loss: 5.7412e-04 - val_loss: 6.2478e-04
# Epoch 18/60
# 19/19 [==============================] - 4s 204ms/step - loss: 5.5909e-04 - val_loss: 6.0814e-04
# Epoch 19/60
# 19/19 [==============================] - 4s 190ms/step - loss: 5.3857e-04 - val_loss: 6.2499e-04
# Epoch 20/60
# 19/19 [==============================] - 3s 156ms/step - loss: 5.0810e-04 - val_loss: 5.6609e-04
# Epoch 21/60
# 19/19 [==============================] - 3s 169ms/step - loss: 4.9322e-04 - val_loss: 5.7185e-04
# Epoch 22/60
# 19/19 [==============================] - 3s 167ms/step - loss: 4.7643e-04 - val_loss: 4.9442e-04
# Epoch 23/60
# 19/19 [==============================] - 3s 153ms/step - loss: 4.5343e-04 - val_loss: 4.8581e-04
# Epoch 24/60
# 19/19 [==============================] - 3s 156ms/step - loss: 4.4097e-04 - val_loss: 5.1017e-04
# Epoch 25/60
# 19/19 [==============================] - 3s 169ms/step - loss: 4.2348e-04 - val_loss: 5.1481e-04
# Epoch 26/60
# 19/19 [==============================] - 3s 167ms/step - loss: 4.1842e-04 - val_loss: 4.0711e-04
# Epoch 27/60
# 19/19 [==============================] - 3s 155ms/step - loss: 3.8939e-04 - val_loss: 3.8612e-04
# Epoch 28/60
# 19/19 [==============================] - 3s 157ms/step - loss: 3.7612e-04 - val_loss: 3.9019e-04
# Epoch 29/60
# 19/19 [==============================] - 3s 168ms/step - loss: 3.6394e-04 - val_loss: 3.3796e-04
# Epoch 30/60
# 19/19 [==============================] - 3s 172ms/step - loss: 3.5594e-04 - val_loss: 3.3356e-04
# Epoch 31/60
# 19/19 [==============================] - 3s 163ms/step - loss: 3.8428e-04 - val_loss: 3.1005e-04
# Epoch 32/60
# 19/19 [==============================] - 3s 167ms/step - loss: 3.3105e-04 - val_loss: 2.9381e-04
# Epoch 33/60
# 19/19 [==============================] - 3s 163ms/step - loss: 3.1320e-04 - val_loss: 2.8204e-04
# Epoch 34/60
# 19/19 [==============================] - 3s 152ms/step - loss: 3.0135e-04 - val_loss: 2.6952e-04
# Epoch 35/60
# 19/19 [==============================] - 3s 153ms/step - loss: 3.0682e-04 - val_loss: 3.1011e-04
# Epoch 36/60
# 19/19 [==============================] - 3s 152ms/step - loss: 3.2744e-04 - val_loss: 2.5301e-04
# Epoch 37/60
# 19/19 [==============================] - 3s 154ms/step - loss: 2.9478e-04 - val_loss: 2.5011e-04
# Epoch 38/60
# 19/19 [==============================] - 3s 155ms/step - loss: 3.1976e-04 - val_loss: 2.4036e-04
# Epoch 39/60
# 19/19 [==============================] - 3s 152ms/step - loss: 2.7664e-04 - val_loss: 2.2726e-04
# Epoch 40/60
# 19/19 [==============================] - 3s 154ms/step - loss: 2.6729e-04 - val_loss: 2.2124e-04
# Epoch 41/60
# 19/19 [==============================] - 3s 153ms/step - loss: 2.5427e-04 - val_loss: 2.3034e-04
# Epoch 42/60
# 19/19 [==============================] - 3s 154ms/step - loss: 2.4825e-04 - val_loss: 2.2794e-04
# Epoch 43/60
# 19/19 [==============================] - 3s 154ms/step - loss: 2.5561e-04 - val_loss: 2.0383e-04
# Epoch 44/60
# 19/19 [==============================] - 4s 187ms/step - loss: 2.5116e-04 - val_loss: 2.0559e-04
# Epoch 45/60
# 19/19 [==============================] - 3s 168ms/step - loss: 2.6797e-04 - val_loss: 2.1022e-04
# Epoch 46/60
# 19/19 [==============================] - 3s 164ms/step - loss: 2.2439e-04 - val_loss: 2.1904e-04
# Epoch 47/60
# 19/19 [==============================] - 3s 154ms/step - loss: 2.3261e-04 - val_loss: 2.8831e-04
# Epoch 48/60
# 19/19 [==============================] - 3s 154ms/step - loss: 2.4126e-04 - val_loss: 2.8265e-04
# Epoch 49/60
# 19/19 [==============================] - 3s 154ms/step - loss: 2.4684e-04 - val_loss: 2.1912e-04
# Epoch 50/60
# 19/19 [==============================] - 3s 153ms/step - loss: 2.5665e-04 - val_loss: 1.7809e-04
# Epoch 51/60
# 19/19 [==============================] - 3s 153ms/step - loss: 2.1311e-04 - val_loss: 1.7436e-04
# Epoch 52/60
# 19/19 [==============================] - 3s 155ms/step - loss: 2.1643e-04 - val_loss: 1.6875e-04
# Epoch 53/60
# 19/19 [==============================] - 3s 155ms/step - loss: 2.0052e-04 - val_loss: 1.7895e-04
# Epoch 54/60
# 19/19 [==============================] - 3s 159ms/step - loss: 2.1342e-04 - val_loss: 1.7875e-04
# Epoch 55/60
# 19/19 [==============================] - 3s 162ms/step - loss: 2.0141e-04 - val_loss: 1.9295e-04
# Epoch 56/60
# 19/19 [==============================] - 3s 155ms/step - loss: 2.1584e-04 - val_loss: 1.6689e-04
# Epoch 57/60
# 19/19 [==============================] - 3s 153ms/step - loss: 2.0410e-04 - val_loss: 1.5602e-04
# Epoch 58/60
# 19/19 [==============================] - 3s 155ms/step - loss: 1.8071e-04 - val_loss: 1.5623e-04
# Epoch 59/60
# 19/19 [==============================] - 3s 152ms/step - loss: 1.7570e-04 - val_loss: 1.4864e-04
# Epoch 60/60
# 19/19 [==============================] - 3s 153ms/step - loss: 1.8589e-04 - val_loss: 1.5818e-04

# %% [markdown]
# <h2>Prediction and Checking Performance</h2>

# %%
test_predict=model.predict(X_test)

# %%
test_predicted=scaler.inverse_transform(test_predict)
test_predicted
# Out:
# array([[142.73622 ],
#        [142.84749 ],
#        [141.64565 ],
#        [138.41528 ],
#        [137.03067 ],
#        [137.09837 ],
#        [138.9574  ],
#        [140.67505 ],
#        [140.48564 ],
#        [139.54372 ],
#        [139.22101 ],
#        [140.94919 ],
#        [141.86745 ],
#        [143.60837 ],
#        [145.97853 ],
#        [142.75172 ],
#        [139.8364  ],
#        [140.2829  ],
#        [141.6891  ],
#        [148.04784 ],
#        [152.35936 ],
#        [153.30063 ],
#        [152.60086 ],
#        [149.87804 ],
#        [150.47069 ],
#        [150.87361 ],
#        [151.62593 ],
#        [153.62305 ],
#        [153.98257 ],
#        [153.48431 ],
#        [153.83473 ],
#        [152.32867 ],
#        [148.47923 ],
#        [142.08609 ],
#        [139.41885 ],
#        [139.54787 ],
#        [140.1022  ],
#        [138.63911 ],
#        [135.31415 ],
#        [130.852   ],
#        [128.62819 ],
#        [128.14919 ],
#        [126.013664],
#        [125.42155 ],
#        [123.08179 ],
#        [120.102165],
#        [119.89026 ],
#        [120.01417 ],
#        [120.535545],
#        [119.295784],
#        [118.21987 ],
#        [117.905   ],
#        [117.092094],
#        [117.47821 ],
#        [119.28082 ],
#        [121.39515 ],
#        [123.435905],
#        [123.87366 ],
#        [123.13531 ],
#        [123.01731 ],
#        [123.280464],
#        [123.15838 ],
#        [123.48076 ],
#        [124.01128 ],
#        [124.21907 ],
#        [124.19335 ],
#        [123.885185],
#        [124.2545  ],
#        [124.8035  ],
#        [125.16108 ],
#        [124.0724  ],
#        [122.846886],
#        [121.337105],
#        [120.08508 ],
#        [118.795105],
#        [119.29987 ],
#        [120.18798 ],
#        [121.31448 ],
#        [122.43003 ],
#        [123.64291 ],
#        [124.73783 ],
#        [125.28032 ],
#        [125.57699 ],
#        [125.437614],
#        [125.17732 ],
#        [124.89262 ],
#        [125.96656 ],
#        [126.38455 ],
#        [127.47172 ],
#        [128.28093 ],
#        [128.54126 ],
#        [128.8839  ],
#        [129.93909 ],
#        [129.21452 ],
#        [128.46788 ],
#        [128.44319 ],
#        [128.74786 ],
#        [129.38557 ],
#        [130.42693 ],
#        [130.53777 ],
#        [130.62442 ],
#        [133.91663 ],
#        [139.17426 ],
#        [143.16386 ],
#        [143.98409 ],
#        [144.98555 ],
#        [144.80266 ],
#        [144.1269  ],
#        [142.78041 ],
#        [141.57985 ],
#        [140.0649  ],
#        [139.89925 ],
#        [140.5635  ],
#        [141.90575 ],
#        [142.86267 ],
#        [142.35522 ],
#        [141.07732 ],
#        [139.97964 ],
#        [139.1028  ],
#        [141.2855  ],
#        [142.5679  ],
#        [143.60487 ],
#        [144.04532 ],
#        [143.73975 ],
#        [142.63185 ],
#        [141.48988 ],
#        [139.23306 ],
#        [138.78046 ],
#        [140.12895 ],
#        [143.28458 ],
#        [145.64427 ],
#        [147.10828 ],
#        [147.20218 ],
#        [145.29996 ],
#        [147.65436 ],
#        [150.60338 ],
#        [150.7082  ],
#        [150.50722 ],
#        [150.5752  ],
#        [150.53374 ],
#        [150.69304 ],
#        [151.59532 ],
#        [152.73819 ],
#        [153.54945 ],
#        [152.54884 ],
#        [151.54837 ],
#        [152.46333 ],
#        [152.81743 ],
#        [151.97884 ],
#        [150.63934 ],
#        [149.24692 ],
#        [149.64804 ],
#        [151.54623 ],
#        [152.47    ],
#        [152.70236 ],
#        [152.44106 ],
#        [153.15804 ],
#        [153.04486 ],
#        [153.07756 ],
#        [155.57544 ],
#        [156.9408  ],
#        [156.48434 ],
#        [154.08876 ],
#        [152.55525 ],
#        [153.12523 ],
#        [154.60527 ],
#        [155.10204 ],
#        [154.20969 ],
#        [154.33636 ],
#        [154.78967 ],
#        [154.18747 ],
#        [150.70741 ],
#        [149.12411 ],
#        [148.48979 ],
#        [146.8867  ],
#        [144.19507 ],
#        [143.2611  ],
#        [145.4808  ],
#        [146.93958 ],
#        [147.11818 ],
#        [148.56357 ],
#        [151.27365 ],
#        [154.12274 ],
#        [155.41469 ],
#        [154.32889 ],
#        [154.25089 ],
#        [154.36089 ],
#        [154.37564 ],
#        [153.27425 ],
#        [154.6804  ],
#        [157.52502 ],
#        [159.58249 ],
#        [159.64018 ],
#        [157.97908 ],
#        [156.92725 ],
#        [156.78484 ],
#        [155.96872 ],
#        [153.44164 ],
#        [149.78021 ],
#        [148.7944  ],
#        [149.12738 ],
#        [150.69432 ],
#        [152.28258 ],
#        [152.07349 ],
#        [154.25182 ],
#        [154.81364 ],
#        [156.37262 ],
#        [162.06859 ],
#        [167.6866  ],
#        [171.96324 ],
#        [174.12495 ],
#        [173.68799 ],
#        [174.27577 ],
#        [173.48163 ],
#        [173.58412 ],
#        [172.16338 ],
#        [171.723   ],
#        [170.91458 ],
#        [171.11752 ],
#        [172.15625 ],
#        [170.57556 ],
#        [169.34056 ],
#        [169.26547 ],
#        [168.33737 ],
#        [166.18262 ],
#        [165.7878  ],
#        [166.14558 ],
#        [168.59293 ],
#        [167.73125 ],
#        [163.87982 ],
#        [158.13968 ],
#        [159.90779 ],
#        [171.30365 ],
#        [186.94452 ],
#        [192.10826 ],
#        [191.83882 ],
#        [191.5049  ],
#        [188.3626  ],
#        [190.39522 ],
#        [192.06618 ],
#        [192.06297 ],
#        [190.20218 ],
#        [193.15863 ],
#        [196.2114  ],
#        [196.63313 ],
#        [193.39842 ],
#        [193.33527 ],
#        [199.64717 ],
#        [202.97472 ],
#        [203.37166 ],
#        [204.15762 ],
#        [206.24928 ],
#        [204.54288 ],
#        [205.84047 ],
#        [206.46883 ],
#        [207.99936 ],
#        [210.44566 ],
#        [209.89603 ],
#        [208.09105 ],
#        [200.88527 ],
#        [194.87938 ],
#        [198.68602 ],
#        [198.35616 ],
#        [199.2912  ],
#        [201.4393  ],
#        [202.40215 ],
#        [201.25366 ],
#        [203.02625 ],
#        [204.49863 ],
#        [204.01811 ],
#        [203.6382  ],
#        [204.37225 ],
#        [206.51779 ],
#        [206.52287 ],
#        [205.62999 ],
#        [205.7591  ],
#        [204.08272 ],
#        [201.84048 ],
#        [200.29195 ],
#        [203.9452  ],
#        [203.57625 ],
#        [204.74661 ],
#        [211.76639 ],
#        [218.4996  ],
#        [220.05795 ],
#        [219.88344 ],
#        [219.16989 ],
#        [218.67561 ],
#        [224.25568 ],
#        [221.8353  ],
#        [218.94951 ],
#        [227.69418 ],
#        [229.92288 ],
#        [227.4827  ],
#        [233.08495 ],
#        [238.59335 ],
#        [240.20029 ],
#        [244.26021 ],
#        [253.80229 ],
#        [256.54373 ],
#        [256.78058 ],
#        [257.6743  ],
#        [260.48145 ],
#        [261.0334  ],
#        [265.98816 ],
#        [264.10645 ],
#        [265.96    ],
#        [265.32382 ],
#        [262.23697 ],
#        [261.63144 ],
#        [258.9922  ],
#        [262.56656 ],
#        [266.0956  ],
#        [271.2435  ],
#        [267.35635 ],
#        [263.84586 ],
#        [263.67606 ],
#        [265.4081  ],
#        [267.81848 ],
#        [273.11325 ],
#        [274.6691  ],
#        [274.38672 ],
#        [275.91345 ],
#        [278.39917 ],
#        [279.0467  ],
#        [279.66565 ],
#        [284.63342 ],
#        [284.7132  ],
#        [283.42407 ],
#        [283.38757 ],
#        [284.08435 ],
#        [284.50012 ],
#        [286.60278 ],
#        [286.08112 ],
#        [285.0803  ],
#        [284.54715 ],
#        [290.23724 ],
#        [290.68744 ],
#        [287.1517  ],
#        [285.04703 ],
#        [280.93628 ],
#        [281.05444 ],
#        [281.41907 ],
#        [280.15784 ],
#        [278.0301  ],
#        [277.4549  ],
#        [276.17828 ],
#        [276.80978 ],
#        [270.24136 ],
#        [266.85492 ],
#        [259.27057 ],
#        [256.03668 ],
#        [252.05222 ],
#        [258.37802 ],
#        [260.39984 ],
#        [258.37872 ],
#        [261.4274  ],
#        [261.51044 ],
#        [259.81464 ],
#        [257.9293  ],
#        [253.71138 ],
#        [249.81381 ],
#        [251.28705 ],
#        [249.5671  ],
#        [253.10655 ],
#        [255.94518 ],
#        [256.8967  ],
#        [257.23346 ],
#        [257.21133 ],
#        [257.8878  ],
#        [257.58694 ],
#        [254.69492 ],
#        [256.26874 ],
#        [254.5464  ],
#        [257.5935  ],
#        [260.01105 ],
#        [260.29855 ],
#        [260.70654 ],
#        [257.21957 ],
#        [249.51895 ],
#        [248.27846 ],
#        [249.54813 ],
#        [247.02461 ],
#        [244.95149 ],
#        [246.91544 ],
#        [248.52144 ],
#        [245.65492 ],
#        [254.35036 ],
#        [256.9702  ],
#        [254.00142 ],
#        [254.65987 ],
#        [255.80612 ],
#        [258.90756 ],
#        [258.81284 ],
#        [257.52148 ],
#        [257.30838 ],
#        [258.35486 ],
#        [260.82468 ],
#        [262.07828 ],
#        [263.7173  ],
#        [265.29654 ],
#        [265.78238 ],
#        [264.51822 ],
#        [263.9451  ],
#        [267.0719  ],
#        [269.17273 ],
#        [269.7607  ],
#        [272.50436 ],
#        [271.1784  ],
#        [267.3554  ],
#        [267.05197 ],
#        [270.68555 ],
#        [269.24677 ],
#        [269.21918 ],
#        [266.03558 ],
#        [266.0593  ],
#        [248.99214 ],
#        [234.88306 ],
#        [232.10892 ],
#        [236.50925 ],
#        [235.2057  ],
#        [232.29224 ],
#        [233.4061  ],
#        [235.91934 ],
#        [238.9517  ],
#        [241.6961  ],
#        [244.16777 ],
#        [243.54732 ],
#        [247.30765 ],
#        [252.05746 ],
#        [250.46632 ],
#        [245.10788 ],
#        [248.55704 ],
#        [252.02922 ],
#        [253.05997 ],
#        [252.75685 ],
#        [250.8067  ],
#        [252.27596 ],
#        [254.18536 ],
#        [258.73575 ],
#        [257.10187 ],
#        [257.45706 ],
#        [253.7771  ],
#        [248.90086 ],
#        [246.27223 ],
#        [248.08708 ],
#        [249.96432 ],
#        [251.34363 ],
#        [250.34064 ],
#        [248.82715 ],
#        [251.53378 ],
#        [250.1517  ],
#        [257.9959  ],
#        [259.35764 ],
#        [255.40315 ],
#        [251.70308 ],
#        [256.21994 ],
#        [258.07465 ],
#        [255.04385 ],
#        [251.28682 ],
#        [247.02031 ],
#        [236.7667  ],
#        [236.41998 ],
#        [232.0904  ],
#        [226.29391 ],
#        [228.04863 ],
#        [232.07376 ],
#        [234.27974 ],
#        [228.62912 ],
#        [227.44179 ],
#        [230.38567 ],
#        [231.76512 ],
#        [234.4876  ],
#        [229.2202  ],
#        [226.57591 ],
#        [226.57887 ],
#        [229.89757 ],
#        [230.0468  ],
#        [228.55229 ],
#        [228.5687  ],
#        [226.74472 ],
#        [226.48257 ],
#        [228.54152 ],
#        [230.37907 ],
#        [232.68388 ],
#        [234.52496 ],
#        [232.33336 ],
#        [228.2651  ],
#        [224.64633 ],
#        [227.5978  ],
#        [227.2711  ],
#        [226.80457 ],
#        [227.49709 ],
#        [226.73932 ],
#        [227.51707 ],
#        [220.36543 ],
#        [216.22131 ],
#        [215.39032 ],
#        [216.78476 ],
#        [216.67146 ],
#        [212.39409 ],
#        [214.4093  ],
#        [222.89944 ],
#        [227.39903 ],
#        [226.49498 ],
#        [225.44771 ],
#        [225.5763  ],
#        [225.46869 ],
#        [227.23521 ],
#        [227.20273 ]], dtype=float32)

# %% [markdown]
# <h2>Calculating the Performance</h2>

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
performance = math.sqrt(mean_squared_error(ytest,test_predict))
performance
# Out:
# 0.05103442793172615
